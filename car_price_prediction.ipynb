# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
path='/content/drive/MyDrive/Colab Notebooks/auto_car_338gqj (1).data'
df=pd.read_csv(path)
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns=headers

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
df.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.isna().head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False              False  False      False       False         False
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["symboling"].head()
# Out:
# 0    3
# 1    1
# 2    2
# 3    2
# 4    2
# Name: symboling, dtype: int64

# %%
df["normalized-losses"]
# Out:
# 0        ?
# 1        ?
# 2      164
# 3      164
# 4        ?
#       ...
# 199     95
# 200     95
# 201     95
# 202     95
# 203     95
# Name: normalized-losses, Length: 204, dtype: object

# %%
df.replace("?",np.NaN,inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
missing_data=df.isnull()
missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
# 5      False              False  False      False       False         False
# 6      False               True  False      False       False         False
# 7      False              False  False      False       False         False
# 8      False               True  False      False       False         False
# 9      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %%
missing_data.sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df["normalized-losses"].dtype
# Out:
# dtype('O')

# %%
avg_norLoss=df["normalized-losses"].astype("float").mean()

# %%
print(avg_norLoss)
# Out:
# 122.0

# %%
df["normalized-losses"].replace(np.nan,avg_norLoss,inplace=True)
df['normalized-losses'].fillna('mean', inplace=True)

# %%
df["normalized-losses"].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['num-of-doors']
# Out:
# 0       two
# 1       two
# 2      four
# 3      four
# 4       two
#        ...
# 199    four
# 200    four
# 201    four
# 202    four
# 203    four
# Name: num-of-doors, Length: 204, dtype: object

# %%
df["num-of-doors"].value_counts()
# Out:
# four    114
# two      88
# Name: num-of-doors, dtype: int64

# %%
df["num-of-doors"].replace(np.nan,'four',inplace=True)

# %%
df_door=df["num-of-doors"].isnull()
df_door.sum()
# Out:
# 0

# %%
avg_bore=df['bore'].astype('float').mean()
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3290499999999996

# %%
df["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
df["stroke"].head()
# Out:
# 0    2.68
# 1    3.47
# 2    3.40
# 3    3.40
# 4    3.40
# Name: stroke, dtype: object

# %%
avg_stroke = df["stroke"].astype("float").mean()
print("Average of stroke:", avg_stroke)
# Out:
# Average of stroke: 3.2582999999999993

# %%
df["stroke"].replace(np.nan,avg_stroke,inplace=True)

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)

df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# Average horsepower: 104.22277227722772

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df_rpm=df['peak-rpm'].isnull()
df_rpm.sum()
# Out:
# 2

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)

df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)
# Out:
# Average peak rpm: 5125.990099009901

# %%
df_rpm=df['peak-rpm'].isnull()
df_rpm.sum()
# Out:
# 0

# %%
missing_df=df.isnull()

missing_df.sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.shape
# Out:
# (204, 26)

# %%
df['price'].replace(np.NaN,0,inplace=True)

# %%
df['price']
# Out:
# 0      16500
# 1      16500
# 2      13950
# 3      17450
# 4      15250
#        ...
# 199    16845
# 200    19045
# 201    21485
# 202    22470
# 203    22625
# Name: price, Length: 204, dtype: object

# %%
missing_df=df.isnull()

missing_df.sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# All missing values are handled

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          1             122.0  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2             122.0         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df["price"]=df["price"].astype("float")

df[["bore","stroke"]]=df[["bore","stroke"]].astype("float")

df["normalized-losses"]=df["normalized-losses"].astype("int")

df['horsepower'] = df['horsepower'].astype('int')

# %%
a = pd.get_dummies(df['make'])
b = pd.get_dummies(df['fuel-type'])
c = pd.get_dummies(df['aspiration'])
d = pd.get_dummies(df['num-of-doors'])
e = pd.get_dummies(df['body-style'])
f = pd.get_dummies(df['drive-wheels'])
g = pd.get_dummies(df['engine-location'])
h = pd.get_dummies(df['engine-type'])
i = pd.get_dummies(df['num-of-cylinders'])
j = pd.get_dummies(df['fuel-system'])

# %%
df = pd.concat([df, a], axis=1)
df = pd.concat([df, b], axis=1)
df = pd.concat([df, c], axis=1)
df = pd.concat([df, d], axis=1)
df = pd.concat([df, e], axis=1)
df = pd.concat([df, f], axis=1)
df = pd.concat([df, g], axis=1)
df = pd.concat([df, h], axis=1)
df = pd.concat([df, i], axis=1)
df = pd.concat([df, j], axis=1)

# %%
df.drop(['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system'],axis=1, inplace=True)

# %%
import seaborn as sns
sns.regplot(x=df["engine-size"], y=df["price"])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
import seaborn as sns
sns.regplot(x=df["horsepower"], y=df["price"])
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
import seaborn as sns
sns.regplot(x=df["stroke"], y=df["price"])
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
df[["engine-size", "horsepower", "price", "highway-mpg",'wheel-base','length','width','height','compression-ratio']].corr()
# Out:
#                    engine-size  horsepower     price  highway-mpg  wheel-base  \
# engine-size           1.000000    0.810711  0.838093    -0.677775    0.573989
# horsepower            0.810711    1.000000  0.703549    -0.771066    0.355932
# price                 0.838093    0.703549  1.000000    -0.688005    0.583474
# highway-mpg          -0.677775   -0.771066 -0.688005     1.000000   -0.552897
# wheel-base            0.573989    0.355932  0.583474    -0.552897    1.000000
# length                0.683830    0.555053  0.685474    -0.706635    0.877612
# width                 0.737042    0.644059  0.697163    -0.681169    0.795115
# height                0.068577   -0.109529  0.160724    -0.113995    0.582603
# compression-ratio     0.029083   -0.205531  0.078072     0.264677    0.249199
#
#                      length     width    height  compression-ratio
# engine-size        0.683830  0.737042  0.068577           0.029083
# ...

# %%
a=df[["engine-size", "horsepower", "price", "highway-mpg",'wheel-base','length','width','height','compression-ratio']]

# %%
x = df[['length','width','engine-size','horsepower']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (163, 4)

# %%
x_test.shape
# Out:
# (41, 4)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state=0)
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([13211.5       ,  8138.        , 11073.        , 12290.        ,
#         7074.        ,  7450.5       ,  6855.        ,  7074.        ,
#        18420.        , 19735.        , 16925.        , 19735.        ,
#        40960.        , 11073.        ,  7999.        ,     0.        ,
#         6855.        , 11459.        ,  5995.        ,  7074.        ,
#        19735.        , 19735.        ,  8235.        ,  9249.        ,
#         7788.        , 10295.        , 19735.        ,  7775.        ,
#        10111.66666667, 16630.        ,  6627.2       ,  9418.        ,
#        10111.66666667, 21105.        ,  6627.2       ,  9279.        ,
#         7395.        ,  8068.        ,  5843.        ,  8058.        ,
#        36880.        ])

# %%
y_test
# Out:
# 82     14869.0
# 155     6938.0
# 172     8948.0
# 191    13845.0
# 94      7799.0
# 143     9233.0
# 32      6529.0
# 97      8249.0
# 198    18950.0
# 67     28248.0
# 9      16430.0
# 201    21485.0
# 48     36000.0
# 174     9988.0
# 92      7349.0
# 18      6295.0
# 33      7129.0
# 169    11199.0
# 50      6095.0
# 88      5499.0
# 69     31600.0
# 68     28176.0
# 184     8195.0
# 146    10198.0
# 157     7898.0
# 38      8845.0
# 66     25552.0
# 183     7995.0
# 60     10595.0
# 106    11900.0
# 20      5572.0
# 0      16500.0
# 59      8495.0
# 11     20970.0
# 117     5572.0
# 79      9959.0
# 52      6695.0
# 118     7957.0
# 151     6488.0
# 163     8238.0
# 128        0.0
# Name: price, dtype: float64

# %%
a={'auctual':y_test, 'predict':y_pred}

# %%
pd.DataFrame(a)
# Out:
#      auctual       predict
# 82   14869.0  13211.500000
# 155   6938.0   8138.000000
# 172   8948.0  11073.000000
# 191  13845.0  12290.000000
# 94    7799.0   7074.000000
# 143   9233.0   7450.500000
# 32    6529.0   6855.000000
# 97    8249.0   7074.000000
# 198  18950.0  18420.000000
# 67   28248.0  19735.000000
# 9    16430.0  16925.000000
# 201  21485.0  19735.000000
# 48   36000.0  40960.000000
# 174   9988.0  11073.000000
# 92    7349.0   7999.000000
# 18    6295.0      0.000000
# 33    7129.0   6855.000000
# 169  11199.0  11459.000000
# 50    6095.0   5995.000000
# 88    5499.0   7074.000000
# 69   31600.0  19735.000000
# 68   28176.0  19735.000000
# 184   8195.0   8235.000000
# 146  10198.0   9249.000000
# 157   7898.0   7788.000000
# 38    8845.0  10295.000000
# 66   25552.0  19735.000000
# 183   7995.0   7775.000000
# 60   10595.0  10111.666667
# 106  11900.0  16630.000000
# 20    5572.0   6627.200000
# 0    16500.0   9418.000000
# 59    8495.0  10111.666667
# ...

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.28813551066838483
